# %%
from preprocess_pipeline_brca_dataset import Create_Pipeline
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import pandas as pd
import numpy as np
# Out:
# Running cells with '.venv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/AlessandroKuz/Documents/GitHub/BRCA-MachineLearning/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# # Load Iniziale Dataset

# %%
df = pd.read_csv(r'../data/DATASET_COMPLETO_BRCA.csv')
# Out:
# C:\Users\AlessandroKuz\AppData\Local\Temp\ipykernel_20784\771487291.py:1: DtypeWarning: Columns (7,11,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'../data/DATASET_COMPLETO_BRCA.csv')

# %%
df["LABEL"] = df["LABEL"].map({"NEG": 0, "POS": 1, "VUS": 2})

# %%
df['LABEL'].value_counts()
# Out:
# LABEL
# 0    37140
# 1     1179
# 2      468
# Name: count, dtype: int64

# %%
masks_label = df['LABEL'] == 2
pre_train_df, predict_df = df[~masks_label], df[masks_label]

# %%
X, y = pre_train_df.drop(['LABEL'], axis=1), pre_train_df['LABEL']
X_pred, y_pred = predict_df.drop(['LABEL'], axis=1), predict_df['LABEL']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)

# %%
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=21, stratify=y_test)

# %% [markdown]
# # Pipeline Preprocessing

# %%
my_pipe = Create_Pipeline()

# %%
X_train = my_pipe.fit_transform(X_train)
# Out:
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_1"] = df["GT"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_2"] = df["GT"].str.split("/").str[1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_EXON"] = df["EXON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_INTRON"] = df["INTRON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = "0/0"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = df["EXON/INTRON_POS"].astype("str")
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_CURR_POS"] = df["EXON/INTRON_POS"].apply(lambda x: x.split("/")[0])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = "19" + df["DATA_NASCITA"].str[-2:]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = pd.to_numeric(df["ANNO_NASCITA"])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA"] = df["ANNO"] - df["ANNO_NASCITA"]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MIN"] = df["ETA_DIAGNOSI"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MAX"] = df["ETA_DIAGNOSI"].str.split("/").str[-1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N_DIAGNOSI"] = df["ETA_DIAGNOSI"].str.count("/") + 1
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_MALE"] = df["IS_MALE"].map({"M": 1, "F": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_SOMATIC"] = df["IS_SOMATIC"].map({"SOMATIC": 1, "GERMLINE": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["VARTYPE"] = df["VARTYPE"].apply(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MOST_SEVERE_CONSEQUENCE"] = df["MOST_SEVERE_CONSEQUENCE"].where(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: fill_value if pd.isna(x) else x)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns, inplace=True)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["REF"] = "X"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ALT"] = "Y"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=col, inplace=True)

# %%
# colonne_fam = []
# for col in X_train.columns:
#     if col.startswith('SEDE_TUMORE_FAMILIARITA'):
#         colonne_fam.append(col)
#     elif col.startswith('AOP'):
#         colonne_fam.append(col)
# # colonne_fam

# for col in X_train.columns:
#     if col.startswith('AOP'):
#         X_test[col] = 0
#         X_val[col] = 0
#     elif col.startswith('SEDE_TUMORE_FAMILIARITA'):
#         X_test[col] = 0
#         X_val[col] = 0

# %%
# for column in colonne_fam:
#     print(X_train[column].value_counts())

# %%
# for col in colonne_fam:
#     if col not in X_test.columns:
#         X_test[col] = 0

# %%
# X_test.columns

# %%
X_test = my_pipe.transform(X_test)
# Out:
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_1"] = df["GT"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_2"] = df["GT"].str.split("/").str[1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_EXON"] = df["EXON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_INTRON"] = df["INTRON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = "0/0"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = df["EXON/INTRON_POS"].astype("str")
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_CURR_POS"] = df["EXON/INTRON_POS"].apply(lambda x: x.split("/")[0])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = "19" + df["DATA_NASCITA"].str[-2:]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = pd.to_numeric(df["ANNO_NASCITA"])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA"] = df["ANNO"] - df["ANNO_NASCITA"]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MIN"] = df["ETA_DIAGNOSI"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MAX"] = df["ETA_DIAGNOSI"].str.split("/").str[-1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N_DIAGNOSI"] = df["ETA_DIAGNOSI"].str.count("/") + 1
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_MALE"] = df["IS_MALE"].map({"M": 1, "F": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_SOMATIC"] = df["IS_SOMATIC"].map({"SOMATIC": 1, "GERMLINE": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["VARTYPE"] = df["VARTYPE"].apply(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MOST_SEVERE_CONSEQUENCE"] = df["MOST_SEVERE_CONSEQUENCE"].where(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: fill_value if pd.isna(x) else x)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns, inplace=True)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["REF"] = "X"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ALT"] = "Y"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=col, inplace=True)

# %%
X_val = my_pipe.transform(X_val)
# Out:
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_1"] = df["GT"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["GT_2"] = df["GT"].str.split("/").str[1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_EXON"] = df["EXON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_INTRON"] = df["INTRON"].apply(lambda x: 0 if pd.isna(x) else 1)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:199: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = "0/0"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_POS"] = df["EXON/INTRON_POS"].astype("str")
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["EXON/INTRON_CURR_POS"] = df["EXON/INTRON_POS"].apply(lambda x: x.split("/")[0])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:206: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = "19" + df["DATA_NASCITA"].str[-2:]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ANNO_NASCITA"] = pd.to_numeric(df["ANNO_NASCITA"])
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA"] = df["ANNO"] - df["ANNO_NASCITA"]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MIN"] = df["ETA_DIAGNOSI"].str.split("/").str[0]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ETA_DIAGNOSI_MAX"] = df["ETA_DIAGNOSI"].str.split("/").str[-1]
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:212: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["N_DIAGNOSI"] = df["ETA_DIAGNOSI"].str.count("/") + 1
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_MALE"] = df["IS_MALE"].map({"M": 1, "F": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:217: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["IS_SOMATIC"] = df["IS_SOMATIC"].map({"SOMATIC": 1, "GERMLINE": 0})
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["VARTYPE"] = df["VARTYPE"].apply(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:224: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MOST_SEVERE_CONSEQUENCE"] = df["MOST_SEVERE_CONSEQUENCE"].where(
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[value_col_name] = 0
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: fill_value if pd.isna(x) else x)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(new_type)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns, inplace=True)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["REF"] = "X"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ALT"] = "Y"
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\preprocess_pipeline_brca_dataset.py:287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=col, inplace=True)

# %% [markdown]
# # Selezione Modello

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

random_forest = RandomForestClassifier()
logistic_regression = LogisticRegression()
svc = SVC()

# %% [markdown]
# # Splitting Normale

# %%
# print x_train where eta is 120
X_train.where(X_train['ETA'] == 119)
# Out:
#        GENE_SYMBOL_BRCA1  GENE_SYMBOL_BRCA2  REF_A  REF_AA  REF_C  REF_G  \
# 27462                NaN                NaN    NaN     NaN    NaN    NaN
# 3248                 NaN                NaN    NaN     NaN    NaN    NaN
# 11050                NaN                NaN    NaN     NaN    NaN    NaN
# 9338                 NaN                NaN    NaN     NaN    NaN    NaN
# 27395                NaN                NaN    NaN     NaN    NaN    NaN
# ...                  ...                ...    ...     ...    ...    ...
# 11197                NaN                NaN    NaN     NaN    NaN    NaN
# 24827                NaN                NaN    NaN     NaN    NaN    NaN
# 32550                NaN                NaN    NaN     NaN    NaN    NaN
# 19607                NaN                NaN    NaN     NaN    NaN    NaN
# 11988                NaN                NaN    NaN     NaN    NaN    NaN
#
#        REF_T  REF_TT  REF_X  ALT_A  ...  IS_INTRON  EXON/INTRON_CURR_POS  ETA  \
# 27462    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 3248     NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 11050    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 9338     NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 27395    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# ...      ...     ...    ...    ...  ...        ...                   ...  ...
# 11197    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 24827    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 32550    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 19607    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
# 11988    NaN     NaN    NaN    NaN  ...        NaN                   NaN  NaN
#
#        ETA_DIAGNOSI_MIN  ETA_DIAGNOSI_MAX  N_DIAGNOSI  AOP_M  AOP_O  AOP_S  \
# 27462               NaN               NaN         NaN    NaN    NaN    NaN
# 3248                NaN               NaN         NaN    NaN    NaN    NaN
# 11050               NaN               NaN         NaN    NaN    NaN    NaN
# 9338                NaN               NaN         NaN    NaN    NaN    NaN
# 27395               NaN               NaN         NaN    NaN    NaN    NaN
# ...                 ...               ...         ...    ...    ...    ...
# 11197               NaN               NaN         NaN    NaN    NaN    NaN
# 24827               NaN               NaN         NaN    NaN    NaN    NaN
# 32550               NaN               NaN         NaN    NaN    NaN    NaN
# 19607               NaN               NaN         NaN    NaN    NaN    NaN
# 11988               NaN               NaN         NaN    NaN    NaN    NaN
#
#        AOP_A
# 27462    NaN
# 3248     NaN
# 11050    NaN
# 9338     NaN
# 27395    NaN
# ...      ...
# 11197    NaN
# 24827    NaN
# 32550    NaN
# 19607    NaN
# 11988    NaN
#
# [22507 rows x 56 columns]

# %%
for col in X_train.columns:
    print(col, X_train[col].unique())
# Out:
# GENE_SYMBOL_BRCA1 [0 1]
# GENE_SYMBOL_BRCA2 [1 0]
# REF_A [0 1]
# REF_AA [0 1]
# REF_C [0 1]
# REF_G [0 1]
# REF_T [0 1]
# REF_TT [1 0]
# REF_X [0 1]
# ALT_A [0 1]
# ALT_C [0 1]
# ALT_G [0 1]
# ALT_T [1 0]
# ALT_TAT [0 1]
# ALT_TT [0 1]
# ALT_Y [0 1]
# IMPACT_HIGH [0 1]
# IMPACT_LOW [1 0]
# IMPACT_MODERATE [0 1]
# IMPACT_MODIFIER [0 1]
# VARTYPE_DEL [0 1]
# VARTYPE_INS [1 0]
# VARTYPE_SOST [0 1]
# MOST_SEVERE_CONSEQUENCE_INTRON_VARIANT [0 1]
# MOST_SEVERE_CONSEQUENCE_MISSENSE_VARIANT [0 1]
# MOST_SEVERE_CONSEQUENCE_OTHER [1 0]
# MOST_SEVERE_CONSEQUENCE_SPLICE_POLYPYRIMIDINE_TRACT_VARIANT [0 1]
# MOST_SEVERE_CONSEQUENCE_STOP_GAINED [0 1]
# MOST_SEVERE_CONSEQUENCE_SYNONYMOUS_VARIANT [0 1]
# IS_MALE [0 1]
# STORIA_FAMILIARE_POS_PER_K_MAMMARIO/OVARICO [1 0]
# STORIA_FAMILIARE_POS_ALTRA_PATOLOGIA [0 1]
# FAMILIARI [0 1]
# CHROM [13 17]
# IS_SOMATIC [0 1]
# STRAND [ 1. -1.]
# CLINPRED_RANKSCORE [5.0000e-01 1.2000e-04 8.4907e-01 2.6000e-04 5.9000e-04 8.5000e-04
#  2.0166e-01 2.4000e-04 1.8323e-01 0.0000e+00 2.5360e-02 2.0750e-02
#  5.6850e-02 2.0244e-01 7.7000e-04 1.4200e-03 1.3855e-01 2.3160e-02
#  6.3279e-01 7.3175e-01 2.6300e-02 2.9597e-01 6.5232e-01 8.6400e-02
#  1.5720e-02 6.0934e-01 9.1190e-02 5.5616e-01 2.9000e-01 6.7260e-02
#  7.8898e-01 8.3000e-04 6.2021e-01 2.0754e-01 4.0965e-01 5.7212e-01
#  1.1640e-02 6.8714e-01 2.8774e-01 2.2411e-01 6.4083e-01 9.0000e-05
#  1.3968e-01 6.0084e-01 4.7939e-01 2.9510e-02 1.4248e-01 1.9190e-02
#  5.0000e-05 2.1569e-01 2.4486e-01 2.2810e-02 6.2080e-02 1.4151e-01
#   59  31  81  34  78  29  80  35  26  27  85  86  92 119]
# ETA_DIAGNOSI_MAX [ 69  57  50  60  67  42  37  32  48  72  54  46  45  56  40  39  61  64
#   55  62  87  28  77  52  51  76  49  71  82  53  30  63  38  73  36  24
#   47  81  66  68  75  25  43  44  33  74  41  70  84  83  65  59 120  58
#   79  23  31  34  78  80  29  35  26  27  85  86  92 119]
# N_DIAGNOSI [1 3 2 4]
# AOP_M [1 0]
# AOP_O [0 1]
# AOP_S [0 1]
# AOP_A [0 1]

# %%
X_train.shape, y_train.shape
# Out:
# ((22507, 56), (30655,))

# %%
random_forest_test = random_forest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\AlessandroKuz\Documents\GitHub\BRCA-MachineLearning\model_selection\brca_machine_learning.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AlessandroKuz/Documents/GitHub/BRCA-MachineLearning/model_selection/brca_machine_learning.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> random_forest_test = random_forest.fit(X_train, y_train)
#
# File c:\Users\AlessandroKuz\.conda\envs\projectWork\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\AlessandroKuz\.conda\envs\projectWork\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File c:\Users\AlessandroKuz\.conda\envs\projectWork\Lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\AlessandroKuz\.conda\envs\projectWork\Lib\site-packages\sklearn\utils\validation.py:1164, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    (...)
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1164 check_consistent_length(X, y)
#    1166 return X, y
#
# File c:\Users\AlessandroKuz\.conda\envs\projectWork\Lib\site-packages\sklearn\utils\validation.py:407, in check_consistent_length(*arrays)
#     405 uniques = np.unique(lengths)
#     406 if len(uniques) > 1:
# --> 407     raise ValueError(
#     408         "Found input variables with inconsistent numbers of samples: %r"
#     409         % [int(l) for l in lengths]
#     410     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [22507, 30655]

# %%
random_forest_test.score(X_val, y_val)

# %%
predictions = random_forest_test.predict(X_val)
# getting unique values of the numpy array
# np.unique(predictions, return_counts=True)
# getting the row where the value is 1
np.where(predictions == 1)

# %%
X_pred.columns

# %%
for col in X_train.columns:
    if col.startswith('AOP'):
        X_pred[col] = 0
    elif col.startswith('SEDE_TUMORE_FAMILIARITA'):
        X_pred[col] = 0

# %%
X_pred.columns

# %%
X_pred = my_pipi.transform(X_pred)

# %%
predictions = random_forest_test.predict(X_pred)

np.unique(predictions, return_counts=True)

# %% [markdown]
# # Splitting con K-fold

# %%
train_fold = StratifiedKFold(n_splits=10, random_state=21, shuffle=True)
val_fold = StratifiedKFold(n_splits=10, random_state=21, shuffle=True)

# %%
for i, (train_index, test_index) in enumerate(train_fold.split(X, X['STRATIFY_COL'])):
    X_train_temp, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train_temp, y_test = y.iloc[train_index], y.iloc[test_index]

    for j, (train_index, val_index) in enumerate(val_fold.split(X_train_temp, X_train_temp['STRATIFY_COL'])):
        X_train, X_val = X_train_temp.iloc[train_index], X_train_temp.iloc[val_index]
        y_train, y_val = y_train_temp.iloc[train_index], y_train_temp.iloc[val_index]

        # Model training and evaluation
        random_forest = RandomForestClassifier()
        random_forest_test = random_forest.fit(X_train, y_train)
        score = random_forest_test.score(X_val, y_val)

        # Model prediction
        predictions = random_forest_test.predict(X_pred)

        # Model evaluation
        np.unique(predictions, return_counts=True)

        # Save model
        import pickle
